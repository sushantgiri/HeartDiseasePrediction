# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd

# %%
# --- Importing Dataset ---
df = pd.read_csv("heart.csv")

# --- Reading Dataset ---
df.head().style.background_gradient(cmap='Reds').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# Out:
# /var/folders/cb/1245rzhj223g8880vj743knc0000gn/T/ipykernel_40947/2271403565.py:5: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   df.head().style.background_gradient(cmap='Reds').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# <style type="text/css">
# #T_c1b9e_row0_col0, #T_c1b9e_row0_col2, #T_c1b9e_row0_col3, #T_c1b9e_row0_col5, #T_c1b9e_row0_col8, #T_c1b9e_row0_col13, #T_c1b9e_row1_col2, #T_c1b9e_row1_col6, #T_c1b9e_row1_col10, #T_c1b9e_row1_col11, #T_c1b9e_row1_col13, #T_c1b9e_row2_col2, #T_c1b9e_row2_col4, #T_c1b9e_row2_col5, #T_c1b9e_row2_col10, #T_c1b9e_row2_col11, #T_c1b9e_row2_col13, #T_c1b9e_row3_col2, #T_c1b9e_row3_col5, #T_c1b9e_row3_col8, #T_c1b9e_row3_col9, #T_c1b9e_row3_col13, #T_c1b9e_row4_col1, #T_c1b9e_row4_col2, #T_c1b9e_row4_col7, #T_c1b9e_row4_col8, #T_c1b9e_row4_col12, #T_c1b9e_row4_col13 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row0_col1, #T_c1b9e_row0_col6, #T_c1b9e_row0_col7, #T_c1b9e_row0_col10, #T_c1b9e_row0_col12, #T_c1b9e_row1_col1, #T_c1b9e_row1_col5, #T_c1b9e_row1_col8, #T_c1b9e_row1_col9, #T_c1b9e_row1_col12, #T_c1b9e_row2_col0, #T_c1b9e_row2_col1, #T_c1b9e_row2_col6, #T_c1b9e_row2_col8, #T_c1b9e_row2_col12, #T_c1b9e_row3_col1, #T_c1b9e_row3_col3, #T_c1b9e_row3_col6, #T_c1b9e_row3_col10, #T_c1b9e_row3_col12, #T_c1b9e_row4_col4, #T_c1b9e_row4_col5, #T_c1b9e_row4_col6, #T_c1b9e_row4_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row0_col4 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row0_col9 {
#   background-color: #fca486;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row0_col11 {
#   background-color: #e32f27;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row1_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row1_col4, #T_c1b9e_row3_col4 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row1_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row2_col3 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row2_col7 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row2_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row3_col0, #T_c1b9e_row4_col10 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row3_col7 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row3_col11 {
#   background-color: #fca082;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row4_col3 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_c1b9e_row4_col9 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_c1b9e">
#   <thead>
#     <tr>
#       <th id="T_c1b9e_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_c1b9e_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_c1b9e_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_c1b9e_level0_col3" class="col_heading level0 col3" >trestbps</th>
#       <th id="T_c1b9e_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_c1b9e_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_c1b9e_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_c1b9e_level0_col7" class="col_heading level0 col7" >thalach</th>
#       <th id="T_c1b9e_level0_col8" class="col_heading level0 col8" >exang</th>
#       <th id="T_c1b9e_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_c1b9e_level0_col10" class="col_heading level0 col10" >slope</th>
#       <th id="T_c1b9e_level0_col11" class="col_heading level0 col11" >ca</th>
#       <th id="T_c1b9e_level0_col12" class="col_heading level0 col12" >thal</th>
#       <th id="T_c1b9e_level0_col13" class="col_heading level0 col13" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1b9e_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_c1b9e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c1b9e_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c1b9e_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_c1b9e_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_c1b9e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c1b9e_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_c1b9e_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_c1b9e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_c1b9e_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_c1b9e_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_c1b9e_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_c1b9e_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_c1b9e_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c1b9e_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_c1b9e_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_c1b9e_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c1b9e_row1_col3" class="data row1 col3" >140</td>
#       <td id="T_c1b9e_row1_col4" class="data row1 col4" >203</td>
#       <td id="T_c1b9e_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_c1b9e_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_c1b9e_row1_col7" class="data row1 col7" >155</td>
#       <td id="T_c1b9e_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_c1b9e_row1_col9" class="data row1 col9" >3.100000</td>
#       <td id="T_c1b9e_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_c1b9e_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_c1b9e_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_c1b9e_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c1b9e_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_c1b9e_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_c1b9e_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c1b9e_row2_col3" class="data row2 col3" >145</td>
#       <td id="T_c1b9e_row2_col4" class="data row2 col4" >174</td>
#       <td id="T_c1b9e_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_c1b9e_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_c1b9e_row2_col7" class="data row2 col7" >125</td>
#       <td id="T_c1b9e_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_c1b9e_row2_col9" class="data row2 col9" >2.600000</td>
#       <td id="T_c1b9e_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_c1b9e_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_c1b9e_row2_col12" class="data row2 col12" >3</td>
#       <td id="T_c1b9e_row2_col13" class="data row2 col13" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c1b9e_row3_col0" class="data row3 col0" >61</td>
#       <td id="T_c1b9e_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_c1b9e_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_c1b9e_row3_col3" class="data row3 col3" >148</td>
#       <td id="T_c1b9e_row3_col4" class="data row3 col4" >203</td>
#       <td id="T_c1b9e_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_c1b9e_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_c1b9e_row3_col7" class="data row3 col7" >161</td>
#       <td id="T_c1b9e_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_c1b9e_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_c1b9e_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_c1b9e_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_c1b9e_row3_col12" class="data row3 col12" >3</td>
#       <td id="T_c1b9e_row3_col13" class="data row3 col13" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c1b9e_row4_col0" class="data row4 col0" >62</td>
#       <td id="T_c1b9e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c1b9e_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_c1b9e_row4_col3" class="data row4 col3" >138</td>
